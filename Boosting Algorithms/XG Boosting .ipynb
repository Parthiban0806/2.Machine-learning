# %%
import XGboost as xg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import XGboost as xg
#
# ModuleNotFoundError: No module named 'XGboost'

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\anaconda\lib\site-packages (from xgboost) (1.15.3)
# Downloading xgboost-3.0.5-py3-none-win_amd64.whl (56.8 MB)
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    - -------------------------------------- 2.4/56.8 MB 11.7 MB/s eta 0:00:05
#    --- ------------------------------------ 4.5/56.8 MB 11.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 7.1/56.8 MB 11.7 MB/s eta 0:00:05
#    ------ --------------------------------- 9.4/56.8 MB 11.7 MB/s eta 0:00:05
#    -------- ------------------------------- 11.8/56.8 MB 11.7 MB/s eta 0:00:04
#    --------- ------------------------------ 14.2/56.8 MB 11.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 16.5/56.8 MB 11.7 MB/s eta 0:00:04
#    ------------- -------------------------- 18.9/56.8 MB 11.7 MB/s eta 0:00:04
#    -------------- ------------------------- 21.2/56.8 MB 11.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 23.6/56.8 MB 11.7 MB/s eta 0:00:03
#    ------------------ --------------------- 26.0/56.8 MB 11.7 MB/s eta 0:00:03
#    -------------------- ------------------- 28.6/56.8 MB 11.7 MB/s eta 0:00:03
#    --------------------- ------------------ 30.9/56.8 MB 11.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 33.3/56.8 MB 11.7 MB/s eta 0:00:03
#    ------------------------ --------------- 35.4/56.8 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 37.7/56.8 MB 11.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 40.4/56.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------------ --------- 42.7/56.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------------- -------- 45.1/56.8 MB 11.7 MB/s eta 0:00:02
#    --------------------------------- ------ 47.4/56.8 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 49.8/56.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 52.2/56.8 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 54.5/56.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 56.8/56.8 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.5

# %%
import xgboost as xg

# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train,x_train.shape
# Out:
# (array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#         [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#         [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#         ...,
#         [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#         [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#         [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]]),
#  (936, 5))

# %%
x_test,x_test.shape
# Out:
# (array([[ 0.89459283, -0.08863026, -0.06746417,  1.02378711, -0.50466988],
#         [ 0.53757957, -0.22180837, -0.06746417, -0.97676557, -0.50466988],
#         [ 0.60898222,  1.57449152,  0.76341038,  1.02378711,  1.98149332],
#         ...,
#         [ 1.10880078,  1.20785059, -0.89833872,  1.02378711, -0.50466988],
#         [ 1.75142463,  1.34905148, -0.06746417,  1.02378711, -0.50466988],
#         [ 1.60861933, -0.92299913, -0.89833872, -0.97676557, -0.50466988]]),
#  (402, 5))

# %%
from xgboost import XGBRegressor
regressor= XGBRegressor()
regressor=regressor.fit(x_train,y_train)

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
R_value=r2_score(y_test,y_pred)

# %%
R_value
# Out:
# 0.8213337063789368
